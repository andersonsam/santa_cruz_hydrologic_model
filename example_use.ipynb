# %% [markdown]
# # Example Use of Santa Cruz Hydrologic Model

# %%
#NOTE: Users must select the proper flag values within HCPHydroDFG5Base_Project2020_CC_AdultRev_UMass.ipynb 
#      that correspond to the scenario type (historical vs future).  
#      This must be done before running the cell below.

# %%
#run the file that defines the main function for simulating streamflow
# %run HCPHydroDFG5Base_Project2020_CC_AdultRev_UMass.ipynb

# %%
#select the file to define the modelling scenario

#comment out all but desired scenario for comparison
# myFiles = ['Historical_SIM.csv']
# myFiles = ['Weather_WBM_dT=2_dP=100_R1270_dCV=1.1.csv']
# myFiles = ['Weather_WBM_dT=2_dP=100_R1956_dCV=1.1.csv']
# myFiles = ['Weather_WBM_dT=2_dP=100_R1987_dCV=1.1.csv']
# myFiles = ['Weather_WBM_dT=2_dP=100_R2770_dCV=1.1.csv']
# myFiles = ['Weather_WBM_dT=2_dP=100_R3449_dCV=1.1.csv']
myFiles = ['Weather_WBM_dT=2_dP=100_R3515_dCV=1.1.csv']

# %%
#run the model -- this saves all variables
HCPHydroDFG5Base_Project2020_CC_AdultRev_UMass(myFiles)
# Out:
# Initializing...
#   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Now reading:
# 	 ./Input_Historical/Weather_WBM_dT=2_dP=100_R3515_dCV=1.1.csv
# heretait
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:58<00:00, 58.95s/it]
# Simulations ran successfully
